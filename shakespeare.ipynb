# %%
import pandas as pd

# %%
drama = 'othello'

# %%
paragraphs = pd.read_csv(f'{drama}.tsv', sep='\t')

# %%
paragraphs.head()
# Out:
#                                               speech    created_at  \
# 0  Tush, never tell me! I take it much unkindly T...  946684800000
# 1  ’Sblood, but you’ll not hear me! If ever I did...  946684800001
# 2    Thou toldst me thou didst hold him in thy hate.  946684800002
# 3  Despise me If I do not. Three great ones of th...  946684800003
# 4   By heaven, I rather would have been his hangman.  946684800004
#
#        character
# 0  #Roderigo_Oth
# 1      #Iago_Oth
# 2  #Roderigo_Oth
# 3      #Iago_Oth
# 4  #Roderigo_Oth

# %%
sentences = paragraphs.copy()

# %%
import nltk
nltk.download('punkt')  # Download the Punkt tokenizer models if you haven't already

from nltk.tokenize import sent_tokenize

sentences['speech_sent'] = sentences['speech'].apply(nltk.sent_tokenize)

sentences = sentences.explode('speech_sent')
# Drop the 'Paragraphs' column if you no longer need it
sentences.drop(columns=['speech'], inplace=True)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zsomk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
sentences
# Out:
#         created_at      character  \
# 0     946684800000  #Roderigo_Oth
# 0     946684800000  #Roderigo_Oth
# 1     946684800001      #Iago_Oth
# 1     946684800001      #Iago_Oth
# 2     946684800002  #Roderigo_Oth
# ...            ...            ...
# 1181  946684801181  #Lodovico_Oth
# 1181  946684801181  #Lodovico_Oth
# 1181  946684801181  #Lodovico_Oth
# 1181  946684801181  #Lodovico_Oth
# 1181  946684801181  #Lodovico_Oth
#
#                                             speech_sent
# 0                                  Tush, never tell me!
# 0     I take it much unkindly That thou, Iago, who h...
# 1                      ’Sblood, but you’ll not hear me!
# 1       If ever I did dream of such a matter, Abhor me.
# 2       Thou toldst me thou didst hold him in thy hate.
# ...                                                 ...
# 1181  Let it be hid.—Gratiano, keep the house, And s...
# 1181                                         To Cassio.
# 1181  To you, lord governor, Remains the censure of ...
# 1181   The time, the place, the torture, O, enforce it.
# 1181  Myself will straight aboard, and to the state ...
#
# [2634 rows x 3 columns]

# %%
from langchain.document_loaders.dataframe import DataFrameLoader
from langchain.embeddings import HuggingFaceEmbeddings, SentenceTransformerEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS

embedder = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2") # or all-mpnet-base-v2

# %%
sentence_embeddings = embedder.embed_documents(sentences['speech_sent'])

# %%
sentences['embeddings'] = sentence_embeddings
sentences.to_csv(f'{drama}_embeddings.csv')

# %%
list(zip(sentences['speech_sent'].values, sentence_embeddings))[0][1]
# Out:
# [0.00986724067479372,
#  -0.007621891796588898,
#  0.03612726926803589,
#  -0.01146914716809988,
#  0.03965059667825699,
#  -0.022295786067843437,
#  0.05211757868528366,
#  -0.05252056568861008,
#  0.012287657707929611,
#  0.05216572433710098,
#  -0.0008633207180537283,
#  -0.10315906256437302,
#  0.006650043185800314,
#  -0.09787499159574509,
#  -0.10406609624624252,
#  -0.031761251389980316,
#  -0.0020388669800013304,
#  -0.07604312151670456,
#  -0.005888249259442091,
#  -0.01777534931898117,
#  -0.047719556838274,
#  0.024277588352560997,
#  -0.009662052616477013,
#  0.005540301091969013,
#  -0.020119033753871918,
#  -0.03749542310833931,
#  0.023493831977248192,
#  0.030902134254574776,
#  -0.144348606467247,
#  -0.05813363194465637,
#  0.0007006678497418761,
#  0.040237609297037125,
#  -0.019360585138201714,
#  0.0844435766339302,
#  -0.024125682190060616,
#  -0.010495745576918125,
#  0.018457068130373955,
#  0.04327243193984032,
#  -0.049661267548799515,
#  0.016581404954195023,
#  -0.10061610490083694,
#  0.010076087899506092,
#  -0.06565598398447037,
#  -0.020469587296247482,
#  -0.07229706645011902,
#  0.01357097178697586,
#  -0.06170809268951416,
#  0.03370540589094162,
#  0.0986323356628418,
#  0.07141038775444031,
#  -0.07340012490749359,
#  0.102516770362854,
#  0.01721755601465702,
#  0.0257937703281641,
#  0.043257761746644974,
#  -0.0027496879920363426,
#  -0.056947533041238785,
#  -0.04277993366122246,
#  -0.05896014720201492,
#  0.05476604029536247,
#  0.01773078180849552,
#  -2.0502019637547164e-08,
#  0.06473619490861893,
#  0.008325086906552315,
#  0.03511347994208336,
#  -0.08358671516180038,
#  -0.10384558141231537,
#  -0.020806988701224327,
#  0.04406481981277466,
#  0.0061396649107337,
#  -0.06656841933727264,
#  0.0012322134571149945,
#  0.027423175051808357,
#  0.07875479757785797,
#  0.029957067221403122,
#  0.055088892579078674,
#  0.06518899649381638,
#  0.11617258191108704,
#  0.04013703018426895,
#  0.02518012560904026,
#  -0.05047832056879997,
#  -0.013511084951460361,
#  -0.08045665174722672,
#  0.04043477401137352,
#  0.018625479191541672,
#  -0.015520610846579075,
#  -0.0345027819275856,
#  0.07702022045850754,
#  0.004000534303486347,
#  0.09473521262407303,
#  0.0033915741369128227,
#  0.034556012600660324,
#  0.024941913783550262,
#  -0.024065300822257996,
#  -0.04763685166835785,
#  0.07669774442911148,
#  -0.04921147599816322,
#  -0.02053571678698063,
#  -0.04419472813606262,
#  -0.02578897215425968,
#  -0.06193173676729202,
#  0.0009882161393761635,
#  0.014329731464385986,
#  -0.011648435145616531,
#  -0.018130412325263023,
#  0.033781420439481735,
#  -0.0681418851017952,
#  0.03243912011384964,
#  0.04790690913796425,
#  -0.0204639695584774,
#  0.03527653217315674,
#  -0.014516918919980526,
#  -0.08827915787696838,
#  0.12047535926103592,
#  0.055759601294994354,
#  0.12762585282325745,
#  0.10006451606750488,
#  -0.009202331304550171,
#  -0.06290502101182938,
#  -0.01722075045108795,
#  -0.004526867531239986,
#  -0.023933472111821175,
#  0.09114260971546173,
#  -0.039869461208581924,
#  0.011299282312393188,
#  -0.02002420462667942]

# %%
text_embedding_pairs = list(zip(sentences['speech_sent'].values, sentence_embeddings))
db = FAISS.from_embeddings(text_embedding_pairs, embedder)

# %%
# Load the document, split it into chunks, embed each chunk and load it into the vector store.
raw_documents = DataFrameLoader(sentences, 'speech_sent').load()
#text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
#documents = text_splitter.split_documents(raw_documents)
db = FAISS.from_documents(raw_documents, embedder)

# %%
db.save_local(f"{drama}.faiss_index")

# %%
db = FAISS.load_local(f"{drama}.faiss_index", embedder)

# %%
db.similarity_search_with_score('If ever I did dream of such a matter, Abhor me.')
# Out:
# [(Document(page_content='If ever I did dream of such a matter, Abhor me.'),
#   3.0471697e-13),
#  (Document(page_content='’Tis a shrewd doubt, though it be but a dream.'),
#   1.0715976),
#  (Document(page_content='This accident is not unlike my dream.'), 1.0934726),
#  (Document(page_content='Pray heaven it be State matters, as you think, and no conception Nor no jealous toy concerning you.'),
#   1.132489)]
